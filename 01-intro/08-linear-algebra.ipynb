# %%
import numpy as np

# %% [markdown]
# ## Vector operations

# %%
u = np.array([2, 4, 5, 6])
print(u)
u * 2
# Out:
# [2 4 5 6]
# array([ 4,  8, 10, 12])

# %%
# Addition works element-wise
v = np.array([1, 0, 0, 2])
u + v
# Out:
# array([3, 4, 5, 8])

# %% [markdown]
# ## Multiplication

# %% [markdown]
# ### Vector-vector multiplication

# %%
# Element-wise multiplication
u * v
# Out:
# array([ 2,  0,  0, 12])

# %%
# Dot product multiplication (u.v = sum (ui*vi) for all i

def dot_product(u, v):
    assert u.shape[0] == v.shape[0]

    n = u.shape[0]
    result = 0.0

    for i in range(n):
        result += u[i] * v[i]

    return result

# %%
dot_p = dot_product(u, v)
dot_p
# Out:
# np.float64(14.0)

# %%
u.dot(v)
# Out:
# np.int64(14)

# %% [markdown]
# ### Matrix-vector multiplication

# %%
U = np.array([
    [2, 4, 5, 6],
    [1, 2, 1, 2],
    [3, 1, 2, 1],
])
U.shape
# Out:
# (3, 4)

# %%
def matrix_vector_multiplication(U, v):
    assert U.shape[1] == v.shape[0]

    num_rows = U.shape[0]

    result = np.zeros(num_rows)

    for i in range(num_rows):
        result[i] = dot_product(U[i], v)

    return result

# %%
matrix_vector_multiplication(U, v)
# Out:
# array([14.,  5.,  5.])

# %%
U.dot(v)
# Out:
# array([14,  5,  5])

# %% [markdown]
# ### Matrix-matrix multiplication

# %%
V = np.array([
    [1, 1, 2],
    [0, 0.5, 1], 
    [0, 2, 1],
    [2, 1, 0],
    ])

# %%
def matrix_matrix_multiplication(U, V):
    assert U.shape[1] == V.shape[0]
    
    num_rows = U.shape[0]
    num_cols = V.shape[1]
    
    result = np.zeros((num_rows, num_cols))
    
    for i in range(num_cols):
        vi = V[:, i]
        Uvi = matrix_vector_multiplication(U, vi)
        result[:, i] = Uvi
    
    return result

# %%
matrix_matrix_multiplication(U, V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
U.dot(V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %% [markdown]
# ## Identity matrix

# %%
I = np.eye(3)
I
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ## Inverse matrix

# %%
Vs = V[[0, 1, 2]]
Vs
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ]])

# %%
Vs_inv = np.linalg.inv(Vs)
Vs_inv
# Out:
# array([[ 1.        , -2.        ,  0.        ],
#        [ 0.        , -0.66666667,  0.66666667],
#        [ 0.        ,  1.33333333, -0.33333333]])

# %%
res = Vs.dot(Vs_inv)
res
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
